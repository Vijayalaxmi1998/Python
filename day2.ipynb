# %% [markdown]
# # standard datatype

# %% [markdown]
# ![image.png](attachment:9c4a295d-7e58-4f06-aa1d-0888a966d686.png)

# %% [markdown]
# # list

# %% [markdown]
# ![image.png](attachment:8d283fdc-ee85-472e-ae3d-938deaec652c.png)

# %%
# printing list
l1=[1,2,3,"apple","orange","banana",3.53,6.8,5+5j,["a","b","c"]]
l1
# Out:
# [1, 2, 3, 'apple', 'orange', 'banana', 3.53, 6.8, (5+5j), ['a', 'b', 'c']]

# %%
print(type(l1))
# Out:
# <class 'list'>

# %% [markdown]
# ##  index in list

# %%
print(l1[4])   # 4th index element in the list
print(l1[-1])  #the print last element in list
# Out:
# orange
# ['a', 'b', 'c']

# %% [markdown]
# ## slice Operation in list  [start:end:step]

# %%
l1[0:3:1]
# Out:
# [1, 2, 3]

# %%
fruit_name=l1[3:6]
fruit_name
# Out:
# ['apple', 'orange', 'banana']

# %% [markdown]
# ## list is mutable

# %%
fruit_name[0]="mango"

# %%
fruit_name
# Out:
# ['mango', 'orange', 'banana']

# %%
l1[5]="vijaya"
l1
# Out:
# [1, 2, 3, 'apple', 'orange', 'vijaya', 3.53, 6.8, (5+5j), ['a', 'b', 'c']]

# %% [markdown]
# ## list copy and alise

# %%
l2=[1,2,3]
l3=l2
print(l3)
# Out:
# [1, 2, 3]

# %%
l2[0]="abc"

# %%
print(l2)      #asigne the object reference from l2 to l3
print(l3)
# Out:
# ['abc', 2, 3]
# ['abc', 2, 3]

# %%
# to assigning problem of assigning in list we use the copy function
l3=l2.copy()
l2
# Out:
# ['abc', 2, 3]

# %%
l2[0]=1
print(l2)
print(l3)
# Out:
# [1, 2, 3]
# ['abc', 2, 3]

# %% [markdown]
# ## Operators in list

# %%
print(l2)
print(l3)
# Out:
# [1, 2, 3]
# ['abc', 2, 3]

# %%
l4=print(l2+l3)    # it is extended the list
# Out:
# [1, 2, 3, 'abc', 2, 3]

# %%
l5=print(l2*3)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# # Tuples (immutable)

# %% [markdown]
# ![image.png](attachment:a3bddea9-9c81-404c-b809-fb21b59aecaa.png)

# %%
tuple=(1,2,3,('a','b','c'),'apple','orange','banana',3.53,6.8,5+6j,['a','b','c'])
tuple
# Out:
# (1,
#  2,
#  3,
#  ('a', 'b', 'c'),
#  'apple',
#  'orange',
#  'banana',
#  3.53,
#  6.8,
#  (5+6j),
#  ['a', 'b', 'c'])

# %%
t1=(1,2,3)
t1
# Out:
# (1, 2, 3)

# %%
print(type(tuple))
# Out:
# <class 'tuple'>

# %% [markdown]
# ## index in Tuple

# %%
print(t1)
# Out:
# (1, 2, 3)

# %%
t1[2]
# Out:
# 3

# %%
tuple[5][-1]
# Out:
# 'e'

# %%
tuple[5].upper()
# Out:
# 'ORANGE'

# %%
tuple[-8]
# Out:
# ('a', 'b', 'c')

# %% [markdown]
# ## slicing in tuple

# %%
tuple
# Out:
# (1,
#  2,
#  3,
#  ('a', 'b', 'c'),
#  'apple',
#  'orange',
#  'banana',
#  3.53,
#  6.8,
#  (5+6j),
#  ['a', 'b', 'c'])

# %%
tuple[3:6]
# Out:
# (('a', 'b', 'c'), 'apple', 'orange')

# %%
tuple[4:9:2]
# Out:
# ('apple', 'banana', 6.8)

# %% [markdown]
# ## tuple is immutable Object

# %%
tuple
# Out:
# (1,
#  2,
#  3,
#  ('a', 'b', 'c'),
#  'apple',
#  'orange',
#  'banana',
#  3.53,
#  6.8,
#  (5+6j),
#  ['a', 'b', 'c'])

# %%
tuple[4]="vijaya"  #TUPLE IS NOT SUPPORTED FOR EXCHANGE OF ITEM
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23508/1003516547.py in <module>
# ----> 1 tuple[4]="vijaya"  #TUPLE IS NOT SUPPORTED FOR EXCHANGE OF ITEM
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (1, 2, 3)

# %%
print(t1+(4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
t2=(1,3,6)
t3=(5,7,9)
t2+t3         # concatenate  the tuple t2 and t3
# Out:
# (1, 3, 6, 5, 7, 9)

# %%
t3*3    # tuple is repeated 3 times
# Out:
# (5, 7, 9, 5, 7, 9, 5, 7, 9)

# %% [markdown]
# # Dictionary

# %% [markdown]
# #### Which data types are hashable in Python?
# In Python, any immutable object (such as an integer, boolean, string, tuple) is hashable, meaning its value does not change during its lifetime. This allows Python to create a unique hash value to identify it, which can be used by dictionaries to track unique keys and sets to track unique values.

# %% [markdown]
# immutable-hashble
# mutable-not hashble

# %% [markdown]
# #### what is hashable?
#  hashable is a feature of Python objects that tells if the object has a hash value or not. If the object has a hash value then it can be used as a key for a dictionary or as an element in a set. An object is hashable if it has a hash value that does not change during its entire lifetime.31-Aug-2020

# %% [markdown]
# ![image.png](attachment:28bca12e-a9d0-4061-b38b-03cc306c6ce7.png)

# %% [markdown]
# ![image.png](attachment:b5d17f52-339b-406c-9dc3-080dc4a5101e.png)

# %% [markdown]
# ![image.png](attachment:87c03323-f755-4185-836e-8a3da2e2e2fa.png)

# %% [markdown]
# ## Dictionary in python

# %%
month_dict={"jan":1,"feb":2,"march":3}
month_dict
# Out:
# {'jan': 1, 'feb': 2, 'march': 3}

# %%
print(type(month_dict))
# Out:
# <class 'dict'>

# %% [markdown]
# ## indexing in dictionary

# %%
month_dict["jan"]
# Out:
# 1

# %%
month_dict["march"]
# Out:
# 3

# %% [markdown]
# ## Dictionary is mutatable

# %%
month_dict["April"]=4    #we add the new key and values

# %%
month_dict
# Out:
# {'jan': 1, 'feb': 2, 'march': 3, 'April': 4}

# %%
month_dict["april"]="5"

# %%
month_dict      ##key is immutable and value is mutable
# Out:
# {'jan': 1, 'feb': 2, 'march': 3, 'April': 4, 'april': '5'}

# %% [markdown]
# ## View the Dictionary value

# %%
month_dict.keys()   #return dict keys in list form
# Out:
# dict_keys(['jan', 'feb', 'march', 'April', 'april'])

# %%
month_dict.values()  #return dict values in list form
# Out:
# dict_values([1, 2, 3, 4, '5'])

# %%
month_dict.items()   #return dict keys and values in the form of pair tupleand list
# Out:
# dict_items([('jan', 1), ('feb', 2), ('march', 3), ('April', 4), ('april', '5')])

# %%
for x in month_dict:
    print(x)
# Out:
# jan
# feb
# march
# April
# april

# %%
for x in month_dict.values():
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for x in month_dict.items():
    print(x)
# Out:
# ('jan', 1)
# ('feb', 2)
# ('march', 3)
# ('April', 4)
# ('april', '5')

# %% [markdown]
# # set

# %% [markdown]
# ![image.png](attachment:a6a0b923-8220-4f53-83da-148f96c52753.png)

# %% [markdown]
# ![image.png](attachment:b75bd067-06f9-4aef-a8d3-dc730310fab9.png)

# %% [markdown]
# ## set in python

# %%
set={"a","b",1,3,3.4,(5,6)}   ##set is unordered element
print(set)
print(type(set))
# Out:
# {1, 3, 3.4, (5, 6), 'a', 'b'}
# <class 'set'>

# %% [raw]
# s2={1,2,3,[5,6]}   # element of set not allowing mutable(changeble) data type
# ## here list ireds mutable

# %%
##note: Set is unorder there is no index and slice operator

# %%
## set is not allowing the duplicate value
s1={1,2,"a","a",5,5}
s1
# Out:
# {1, 2, 5, 'a'}

# %% [markdown]
# ## set is mutable

# %%
set
# Out:
# {(5, 6), 1, 3, 3.4, 'a', 'b'}

# %%
set.add(100)    ## add the value 100 to set

# %%
set
# Out:
# {(5, 6), 1, 100, 3, 3.4, 'a', 'b'}

# %%
## set Operations
A={1,2,3,4,5}
B={3,4,5,6,7}

# %% [markdown]
# ## set difference

# %%
print(A-B)
# Out:
# {1, 2}

# %%
print(B-A)
# Out:
# {6, 7}

# %%
print(A&B)  # intersection
# Out:
# {3, 4, 5}

# %%
print(A|B)  # union
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
A.difference(B)
# Out:
# {1, 2}

# %% [markdown]
# # Frozenset   (immutable)

# %%
## is immutable and denoted by ([])

# %%
A={1,2,3,4,5}
f_set=frozenset(A)
print(f_set)
print(type(f_set))
# Out:
# frozenset({1, 2, 3, 4, 5})
# <class 'frozenset'>

# %%
f_set.add(8)  # frozenset added new element it is mutable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10088/4166290658.py in <module>
# ----> 1 f_set.add(8)  # frozenset added new element it is mutable
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %% [markdown]
# ## frozenset operation

# %%
A={1,2,3,4}
B={3,4,5,6}

# %%
f_setA=frozenset(A)
f_setB=frozenset(B)

# %%
f_setA-f_setB
# Out:
# frozenset({1, 2})

# %%
f_setA&f_setB
# Out:
# frozenset({3, 4})

# %%
f_setA|f_setB
# Out:
# frozenset({1, 2, 3, 4, 5, 6})

# %% [markdown]
# # Boolean

# %%
b1=True
type(b1)
# Out:
# bool

# %%
b2=False
type(b2)
# Out:
# bool

# %%
c=None
type(c)
# Out:
# NoneType

# %%
bool()
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool(" ")
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool("vijaya")
# Out:
# True

# %%
bool(3)
# Out:
# True

# %%
bool((2,3))
# Out:
# True

# %%
## Boolean Operation

# %%
a=2
b=4
print(bool(b<a))
print(bool(b>a))
# Out:
# False
# True
